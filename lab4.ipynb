# %%
x = input('Enter a DNA sequence: ')
ct_a = 0
for i in range(len(x)):
    if x[i] == 'a':
        ct_a += 1
print(ct_a)

# %%
def is_pall():
    x = input('Enter a string: ').lower().replace(' ', '')
    return x == x[::-1]

is_pall()
# Out:
# Enter a string:  hiih
# True

# %%
file = open("C:/Users/Sameh.Tawafsheh/OneDrive\Desktop/aa.txt", "r")
line_count, word_count, letter_count = 0, 0, 0
for line in file:
    line_count += 1
    for word in line.split():
        word_count += 1
        for letter in word:
            letter_count += 1
print ('lines:', line_count , ' ', 'words:', word_count,  ' ', 'letters:', letter_count)

# %%
file = open("C:/Users/Sameh.Tawafsheh/OneDrive\Desktop/aa.txt", "r")
vowels = 'aeiou'
vowel_count = 0
for line in file:
    for word in line.split():
        for letter in word:
            vowel_count += letter.lower() in vowels
                
print (vowel_count)
